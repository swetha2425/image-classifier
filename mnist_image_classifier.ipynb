# %% [markdown]
# # MNIST Image Classifier using TensorFlow
#
# This project trains a neural network to classify handwritten digits (0–9) using the MNIST dataset.

# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print("Training images:", x_train.shape)
print("Training labels:", y_train.shape)
print("Testing images:", x_test.shape)
print("Testing labels:", y_test.shape)
# Out:
# Training images: (60000, 28, 28)
# Training labels: (60000,)
# Testing images: (10000, 28, 28)
# Testing labels: (10000,)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

print("Data normalized successfully!")
# Out:
# Data normalized successfully!

# %%
# Build the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

print("Model created successfully!")
# Out:
# c:\Users\sweth\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model created successfully!

# %%
# Compile the model
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model compiled successfully!")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model compiled successfully!

# %%
# Train the model
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9226 - loss: 0.2685
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9652 - loss: 0.1176
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9752 - loss: 0.0804
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9810 - loss: 0.0602
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9858 - loss: 0.0458

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9767 - loss: 0.0804
# Test Accuracy: 0.9767000079154968

# %%
# Make predictions
predictions = model.predict(x_test)

print("Prediction for first image:", predictions[0])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Prediction for first image: [5.3871227e-09 1.0586594e-08 2.6073503e-06 1.6340832e-04 5.4521051e-11
#  4.2881229e-08 2.2042848e-13 9.9983275e-01 1.0303558e-07 1.0641304e-06]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Display the first test image
plt.imshow(x_test[0], cmap="gray")
plt.title("Actual Label: " + str(y_test[0]))
plt.axis("off")
plt.show()

# AI prediction
predicted_label = np.argmax(predictions[0])
print("AI Predicted:", predicted_label)
# Out:
# AI Predicted: 7

# %%
import numpy as np

predicted_label = np.argmax(predictions[0])

print("Actual Label:", y_test[0])
print("Predicted Label:", predicted_label)
# Out:
# Actual Label: 7
# Predicted Label: 7

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9767 - loss: 0.0804
# Test Accuracy: 0.9767000079154968

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow(x_test[0], cmap="gray")
plt.title("Actual Label: " + str(y_test[0]))
plt.axis("off")
plt.show()

predicted_label = np.argmax(predictions[0])
print("Predicted Label:", predicted_label)
# Out:
# Predicted Label: 7
